# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 6.6 MB/s
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (2.6.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.19.5)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
cd /content/drive/MyDrive/컴퓨터비전
# Out:
# /content/drive/MyDrive/컴퓨터비전

# %% [markdown]
# # MTCNN 이미지 얼굴 인식

# %%
from mtcnn import MTCNN
import cv2
import numpy as np   
import os
from tensorflow.keras.preprocessing.image import img_to_array, ImageDataGenerator
from tensorflow.keras.models import load_model
from tqdm import tqdm

img = cv2.imread("./image/image.jpg", cv2.IMREAD_UNCHANGED)
model = load_model("./data/model/0.9011-0.6676.hdf5")
EMOTIONS = ["Angry" ,"Disgusting","Fearful", "Happy", "Sad", "Surpring", "Neutral"]
detector = MTCNN()
faces = detector.detect_faces(img)

for face in tqdm(faces):
    box = face.get("box")
    x, y, w, h = box

    img_ROI = img[y:y+h, x:x+w]   
    img_ROI = cv2.resize(img_ROI, (48, 48))  
    img_ROI = cv2.cvtColor(img_ROI, cv2.COLOR_BGR2GRAY)   
    img_ROI = img_ROI.astype('float') / 255.0  
    img_ROI = img_to_array(img_ROI)  
    img_ROI = np.expand_dims(img_ROI, axis=0)
    result = EMOTIONS[np.argmax(model.predict(img_ROI)[0])]
    
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2, 5)
    cv2.putText(img, result, (int(x), int(y-5)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)

cv2.imwrite('./output/result_image.jpg', img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 17.28it/s]

# %% [markdown]
# # MTCNN 비디오 얼굴 인식

# %%
from mtcnn import MTCNN
import cv2
import numpy as np   
import os
from tensorflow.keras.preprocessing.image import img_to_array, ImageDataGenerator
from tensorflow.keras.models import load_model
import time

video_input_path = './video/test_video.mp4'
video_output_path = './output/result_video5.mp4'

cap = cv2.VideoCapture(video_input_path)
frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))    ## 프레임 갯수
print('총 Frame 갯수:', frame_cnt)

codec = cv2.VideoWriter_fourcc(*'XVID')
vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))) 
vid_fps = cap.get(cv2.CAP_PROP_FPS )
vid_writer = cv2.VideoWriter(video_output_path, codec, vid_fps, vid_size)     ## 비디오 저장

model = load_model("./data/model/0.9011-0.6676.hdf5", compile=False)
EMOTIONS = ["Angry" ,"Disgusting","Fearful", "Happy", "Sad", "Surpring", "Neutral"]
detector = MTCNN()
start= time.time()

cnt = 1
while True:
    ret, frame = cap.read()
    if not ret:
        print('더 이상 처리할 frame이 없습니다.')
        break
    frame_copy = frame.copy()
    frame_copy = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    faces = detector.detect_faces(frame_copy)
    
    for face in faces:
        box = face.get("box")
        x, y, w, h = box
        
        img_ROI = frame[y:y+h, x:x+w]   
        img_ROI = cv2.resize(img_ROI, (48, 48))  
        img_ROI = cv2.cvtColor(img_ROI, cv2.COLOR_BGR2GRAY)   
        img_ROI = img_ROI.astype('float') / 255.0  
        img_ROI = img_to_array(img_ROI)  
        img_ROI = np.expand_dims(img_ROI, axis=0)
        result = EMOTIONS[np.argmax(model.predict(img_ROI)[0])]
        
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2, 5)
        cv2.putText(frame, result, (int(x), int(y-5)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        
    print('{0} frame 수행 시간:'.format(cnt), round(time.time()-start, 2),'초')
    vid_writer.write(frame)
    cnt += 1

print('저장 완료 시간:', round(time.time()-start, 4),'초')
vid_writer.release()
cap.release()
# Out:
# 총 Frame 갯수: 256
# 1 frame 수행 시간: 1.27 초
# 2 frame 수행 시간: 1.89 초
# 3 frame 수행 시간: 2.52 초
# 4 frame 수행 시간: 3.17 초
# 5 frame 수행 시간: 3.79 초
# 6 frame 수행 시간: 4.48 초
# 7 frame 수행 시간: 5.14 초
# 8 frame 수행 시간: 5.8 초
# 9 frame 수행 시간: 6.49 초
# 10 frame 수행 시간: 7.19 초
# 11 frame 수행 시간: 7.87 초
# 12 frame 수행 시간: 8.57 초
# 13 frame 수행 시간: 9.28 초
# 14 frame 수행 시간: 9.97 초
# 15 frame 수행 시간: 10.65 초
# 16 frame 수행 시간: 11.33 초
# 17 frame 수행 시간: 11.99 초
# 18 frame 수행 시간: 12.66 초
# 19 frame 수행 시간: 13.37 초
# 20 frame 수행 시간: 14.07 초
# 21 frame 수행 시간: 14.76 초
# 22 frame 수행 시간: 15.45 초
# 23 frame 수행 시간: 16.16 초
# 24 frame 수행 시간: 16.85 초
# 25 frame 수행 시간: 17.52 초
# 26 frame 수행 시간: 18.42 초
# 27 frame 수행 시간: 19.1 초
# 28 frame 수행 시간: 19.79 초
# 29 frame 수행 시간: 20.49 초
# 30 frame 수행 시간: 21.19 초
# 31 frame 수행 시간: 21.92 초
# 32 frame 수행 시간: 22.6 초
# 33 frame 수행 시간: 23.29 초
# 34 frame 수행 시간: 24.01 초
# 35 frame 수행 시간: 24.7 초
# 36 frame 수행 시간: 25.42 초
# 37 frame 수행 시간: 26.12 초
# 38 frame 수행 시간: 26.8 초
# 39 frame 수행 시간: 27.51 초
# 40 frame 수행 시간: 28.2 초
# 41 frame 수행 시간: 28.89 초
# 42 frame 수행 시간: 29.59 초
# 43 frame 수행 시간: 30.27 초
# 44 frame 수행 시간: 30.96 초
# 45 frame 수행 시간: 31.62 초
# 46 frame 수행 시간: 32.23 초
# 47 frame 수행 시간: 32.84 초
# 48 frame 수행 시간: 33.44 초
# 49 frame 수행 시간: 34.07 초
# 50 frame 수행 시간: 34.75 초
# 51 frame 수행 시간: 35.43 초
# 52 frame 수행 시간: 36.15 초
# 53 frame 수행 시간: 36.83 초
# 54 frame 수행 시간: 37.48 초
# 55 frame 수행 시간: 38.15 초
# 56 frame 수행 시간: 38.8 초
# 57 frame 수행 시간: 39.5 초
# 58 frame 수행 시간: 40.19 초
# 59 frame 수행 시간: 40.86 초
# 60 frame 수행 시간: 41.54 초
# 61 frame 수행 시간: 42.21 초
# 62 frame 수행 시간: 43.0 초
# 63 frame 수행 시간: 43.7 초
# 64 frame 수행 시간: 44.43 초
# 65 frame 수행 시간: 45.15 초
# 66 frame 수행 시간: 46.05 초
# 67 frame 수행 시간: 46.77 초
# 68 frame 수행 시간: 47.49 초
# 69 frame 수행 시간: 48.17 초
# 70 frame 수행 시간: 48.87 초
# 71 frame 수행 시간: 49.56 초
# 72 frame 수행 시간: 50.27 초
# 73 frame 수행 시간: 50.96 초
# 74 frame 수행 시간: 51.68 초
# 75 frame 수행 시간: 52.41 초
# 76 frame 수행 시간: 53.11 초
# 77 frame 수행 시간: 53.82 초
# 78 frame 수행 시간: 54.56 초
# 79 frame 수행 시간: 55.35 초
# 80 frame 수행 시간: 56.06 초
# 81 frame 수행 시간: 56.76 초
# 82 frame 수행 시간: 57.42 초
# 83 frame 수행 시간: 58.07 초
# 84 frame 수행 시간: 58.67 초
# 85 frame 수행 시간: 59.3 초
# 86 frame 수행 시간: 59.9 초
# 87 frame 수행 시간: 60.54 초
# 88 frame 수행 시간: 61.15 초
# 89 frame 수행 시간: 61.78 초
# 90 frame 수행 시간: 62.38 초
# 91 frame 수행 시간: 63.0 초
# 92 frame 수행 시간: 63.62 초
# 93 frame 수행 시간: 64.26 초
# 94 frame 수행 시간: 64.94 초
# 95 frame 수행 시간: 65.64 초
# 96 frame 수행 시간: 66.31 초
# 97 frame 수행 시간: 66.95 초
# 98 frame 수행 시간: 67.6 초
# 99 frame 수행 시간: 68.29 초
# 100 frame 수행 시간: 68.99 초
# 101 frame 수행 시간: 69.63 초
# 102 frame 수행 시간: 70.26 초
# 103 frame 수행 시간: 70.89 초
# 104 frame 수행 시간: 71.57 초
# 105 frame 수행 시간: 72.26 초
# 106 frame 수행 시간: 73.11 초
# 107 frame 수행 시간: 73.81 초
# 108 frame 수행 시간: 74.45 초
# 109 frame 수행 시간: 75.15 초
# 110 frame 수행 시간: 75.86 초
# 111 frame 수행 시간: 76.58 초
# 112 frame 수행 시간: 77.29 초
# 113 frame 수행 시간: 78.02 초
# 114 frame 수행 시간: 78.75 초
# 115 frame 수행 시간: 79.45 초
# 116 frame 수행 시간: 80.12 초
# 117 frame 수행 시간: 80.81 초
# 118 frame 수행 시간: 81.5 초
# 119 frame 수행 시간: 82.16 초
# 120 frame 수행 시간: 82.86 초
# 121 frame 수행 시간: 83.53 초
# 122 frame 수행 시간: 84.2 초
# 123 frame 수행 시간: 84.85 초
# 124 frame 수행 시간: 85.54 초
# 125 frame 수행 시간: 86.2 초
# 126 frame 수행 시간: 86.88 초
# 127 frame 수행 시간: 87.56 초
# 128 frame 수행 시간: 88.22 초
# 129 frame 수행 시간: 88.83 초
# 130 frame 수행 시간: 89.44 초
# 131 frame 수행 시간: 90.05 초
# 132 frame 수행 시간: 90.64 초
# 133 frame 수행 시간: 91.24 초
# 134 frame 수행 시간: 91.81 초
# 135 frame 수행 시간: 92.39 초
# 136 frame 수행 시간: 93.02 초
# 137 frame 수행 시간: 93.65 초
# 138 frame 수행 시간: 94.27 초
# 139 frame 수행 시간: 94.88 초
# 140 frame 수행 시간: 95.5 초
# 141 frame 수행 시간: 96.12 초
# 142 frame 수행 시간: 96.76 초
# 143 frame 수행 시간: 97.43 초
# 144 frame 수행 시간: 98.12 초
# 145 frame 수행 시간: 99.01 초
# 146 frame 수행 시간: 99.69 초
# 147 frame 수행 시간: 100.35 초
# 148 frame 수행 시간: 101.02 초
# 149 frame 수행 시간: 101.71 초
# 150 frame 수행 시간: 102.37 초
# 151 frame 수행 시간: 103.05 초
# 152 frame 수행 시간: 103.76 초
# 153 frame 수행 시간: 104.42 초
# 154 frame 수행 시간: 105.13 초
# 155 frame 수행 시간: 105.76 초
# 156 frame 수행 시간: 106.43 초
# 157 frame 수행 시간: 107.08 초
# 158 frame 수행 시간: 107.76 초
# 159 frame 수행 시간: 108.48 초
# 160 frame 수행 시간: 109.16 초
# 161 frame 수행 시간: 109.83 초
# 162 frame 수행 시간: 110.52 초
# 163 frame 수행 시간: 111.2 초
# 164 frame 수행 시간: 111.86 초
# 165 frame 수행 시간: 112.55 초
# 166 frame 수행 시간: 113.21 초
# 167 frame 수행 시간: 113.88 초
# 168 frame 수행 시간: 114.54 초
# 169 frame 수행 시간: 115.19 초
# 170 frame 수행 시간: 115.85 초
# 171 frame 수행 시간: 116.53 초
# 172 frame 수행 시간: 117.19 초
# 173 frame 수행 시간: 117.89 초
# 174 frame 수행 시간: 118.55 초
# 175 frame 수행 시간: 119.22 초
# 176 frame 수행 시간: 119.87 초
# 177 frame 수행 시간: 120.53 초
# 178 frame 수행 시간: 121.2 초
# 179 frame 수행 시간: 121.88 초
# 180 frame 수행 시간: 122.52 초
# 181 frame 수행 시간: 123.19 초
# 182 frame 수행 시간: 123.83 초
# 183 frame 수행 시간: 124.46 초
# 184 frame 수행 시간: 125.12 초
# 185 frame 수행 시간: 125.89 초
# 186 frame 수행 시간: 126.46 초
# 187 frame 수행 시간: 126.99 초
# 188 frame 수행 시간: 127.57 초
# 189 frame 수행 시간: 128.18 초
# 190 frame 수행 시간: 128.74 초
# 191 frame 수행 시간: 129.35 초
# 192 frame 수행 시간: 129.93 초
# 193 frame 수행 시간: 130.48 초
# 194 frame 수행 시간: 131.03 초
# 195 frame 수행 시간: 131.58 초
# 196 frame 수행 시간: 132.15 초
# 197 frame 수행 시간: 132.71 초
# 198 frame 수행 시간: 133.24 초
# 199 frame 수행 시간: 133.81 초
# 200 frame 수행 시간: 134.33 초
# 201 frame 수행 시간: 134.9 초
# 202 frame 수행 시간: 135.47 초
# 203 frame 수행 시간: 136.03 초
# 204 frame 수행 시간: 136.59 초
# 205 frame 수행 시간: 137.15 초
# 206 frame 수행 시간: 137.76 초
# 207 frame 수행 시간: 138.37 초
# 208 frame 수행 시간: 138.98 초
# 209 frame 수행 시간: 139.55 초
# 210 frame 수행 시간: 140.11 초
# 211 frame 수행 시간: 140.68 초
# 212 frame 수행 시간: 141.24 초
# 213 frame 수행 시간: 141.86 초
# 214 frame 수행 시간: 142.48 초
# 215 frame 수행 시간: 143.1 초
# 216 frame 수행 시간: 143.69 초
# 217 frame 수행 시간: 144.28 초
# 218 frame 수행 시간: 144.88 초
# 219 frame 수행 시간: 145.48 초
# 220 frame 수행 시간: 146.08 초
# 221 frame 수행 시간: 146.69 초
# 222 frame 수행 시간: 147.31 초
# 223 frame 수행 시간: 147.94 초
# 224 frame 수행 시간: 148.56 초
# 225 frame 수행 시간: 149.2 초
# 226 frame 수행 시간: 149.8 초
# 227 frame 수행 시간: 150.41 초
# 228 frame 수행 시간: 151.04 초
# 229 frame 수행 시간: 151.82 초
# 230 frame 수행 시간: 152.46 초
# 231 frame 수행 시간: 153.06 초
# 232 frame 수행 시간: 153.67 초
# 233 frame 수행 시간: 154.27 초
# 234 frame 수행 시간: 154.91 초
# 235 frame 수행 시간: 155.53 초
# 236 frame 수행 시간: 156.16 초
# 237 frame 수행 시간: 156.84 초
# 238 frame 수행 시간: 157.47 초
# 239 frame 수행 시간: 158.07 초
# 240 frame 수행 시간: 158.7 초
# 241 frame 수행 시간: 159.33 초
# 242 frame 수행 시간: 159.95 초
# 243 frame 수행 시간: 160.56 초
# 244 frame 수행 시간: 161.17 초
# 245 frame 수행 시간: 161.77 초
# 246 frame 수행 시간: 162.37 초
# 247 frame 수행 시간: 163.05 초
# 248 frame 수행 시간: 163.72 초
# 249 frame 수행 시간: 164.41 초
# 250 frame 수행 시간: 165.11 초
# 251 frame 수행 시간: 165.83 초
# 252 frame 수행 시간: 166.49 초
# 253 frame 수행 시간: 167.17 초
# 254 frame 수행 시간: 167.83 초
# 255 frame 수행 시간: 168.51 초
# 256 frame 수행 시간: 169.18 초
# 더 이상 처리할 frame이 없습니다.
# 저장 완료 시간: 169.1793 초
